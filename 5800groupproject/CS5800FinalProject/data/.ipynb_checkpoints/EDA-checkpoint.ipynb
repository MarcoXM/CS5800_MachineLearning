# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## The dataset describes diagnosing of cardiac Single Proton Emission Computed Tomography (SPECT) images

# %% [markdown]
# ### training 80 instances, half 1s,half 0s.

# %%
col = ['target','F1R','F1S','F2R','F2S','F3R','F3S','F4R','F4S','F5R','F5S','F6R','F6S','F7R','F7S','F8R','F8S','F9R','F9S','F10R','F10S',
      'F11R','F11S','F12R','F12S','F13R','F13S','F14R','F14S','F15R','F15S','F16R','F16S','F17R','F17S','F18R','F18S',
      'F19R','F19S','F20R','F20S','F21R','F21S','F22R','F22S']

train = pd.read_csv('SPECTF_train.csv', header=None, low_memory=False,names = col,)
train.head()
# Out:
#    target  F1R  F1S  F2R  F2S  F3R  F3S  F4R  F4S  F5R  ...   F18R  F18S  \
# 0       1   59   52   70   67   73   66   72   61   58  ...     66    56
# 1       1   72   62   69   67   78   82   74   65   69  ...     65    71
# 2       1   71   62   70   64   67   64   79   65   70  ...     73    70
# 3       1   69   71   70   78   61   63   67   65   59  ...     61    61
# 4       1   70   66   61   66   61   58   69   69   72  ...     67    69
#
#    F19R  F19S  F20R  F20S  F21R  F21S  F22R  F22S
# 0    62    56    72    62    74    74    64    67
# 1    63    60    69    73    67    71    56    58
# 2    66    65    64    55    61    41    51    46
# 3    66    65    72    73    68    68    59    63
# 4    70    66    70    64    60    55    49    41
#
# [5 rows x 45 columns]

# %% [markdown]
# ## testing 187 instance,15 0s, 172 1s

# %%
test = pd.read_csv('SPECTF_test.csv', header=None, low_memory=False,names = col)
test.head(),test.shape
# Out:
# (   target  F1R  F1S  F2R  F2S  F3R  F3S  F4R  F4S  F5R  ...   F18R  F18S  \
#  0       1   67   68   73   78   65   63   67   60   63  ...     61    56
#  1       1   75   74   71   71   62   58   70   64   71  ...     66    62
#  2       1   83   64   66   67   67   74   74   72   64  ...     67    64
#  3       1   72   66   65   65   64   61   71   78   73  ...     69    68
#  4       1   62   60   69   61   63   63   70   68   70  ...     66    66
#
#     F19R  F19S  F20R  F20S  F21R  F21S  F22R  F22S
#  0    76    75    74    77    76    74    59    68
#  1    68    69    69    66    64    58    57    52
#  2    69    63    68    54    65    64    43    42
#  3    68    63    71    72    65    63    58    60
#  4    58    56    72    73    71    64    49    42
#
#  [5 rows x 45 columns], (187, 45))

# %%
import seaborn as sns
import matplotlib.pyplot as plt
correlation = train.corr()

# %%
plt.figure(figsize=(8,6),dpi=300)
sns.heatmap(correlation,vmax=1,square=True)
plt.title('correlation between features and target')
# Out:
# Text(0.5, 1.0, 'correlation between features and target')

# %% [markdown]
# ## feature reduction

# %%
from sklearn.preprocessing import StandardScaler
import numpy as np
scaler = StandardScaler()
# z = (x - u) / s
y = test['target'].values
X = test.drop('target',axis = 1).values
X_std = scaler.fit_transform(X)
## PCA
from sklearn.decomposition import PCA
pca = PCA(n_components=20).fit(X_std)
plt.figure(figsize=(8,6),dpi=300)
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('Number of Components')
plt.ylabel('Cumulative explained variance')
plt.annotate('15',xy = (15,0.9))
# Out:
# /anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:590: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:590: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# Text(15, 0.9, '15')

# %%
final_data=pca.fit_transform(X_std)

# %%
final_data[:5,:]
# Out:
# array([[-2.83517148,  2.06288369, -1.49743484, -0.97015587,  0.69615422,
#         -1.305284  ,  0.90915489,  1.28340217,  0.49485421, -0.8300328 ,
#          0.66210967,  1.28568284, -0.66069308,  0.40920275, -0.28999989,
#         -0.15002106, -0.01727607, -0.22533626,  0.33363946, -0.01661735],
#        [-2.02888194, -0.17127715, -1.38272881, -0.52486175, -0.3246967 ,
#         -0.06885853,  0.33330699,  0.57830804, -0.1662695 ,  0.04237092,
#          0.64838357,  1.11420305,  0.59103486,  0.91463005, -0.20895565,
#          0.13625165,  0.75552577, -0.08834014,  0.0670143 , -0.0133629 ],
#        [-2.25645259,  0.63169171, -1.1764974 , -0.13374146, -1.8586311 ,
#          0.85755987,  0.19623377,  0.63368707, -0.02264444,  0.86802977,
#         -0.63539998, -0.48423996,  0.70583715,  0.69063094, -1.23982431,
#          0.19062826, -0.39906948,  0.11102845, -0.59603005,  0.14274102],
#        [-2.33437422, -0.82343749,  1.05299359,  0.13842062, -0.04307433,
#         -0.73687547, -0.48108329,  0.18845953, -0.88556561,  0.09956107,
#         -0.11379291,  0.10529173,  0.41316983,  0.46696027, -0.61984049,
#          0.48194886,  0.34401961,  0.29901328,  0.58663023,  0.29623786],
#        [-2.18344184,  0.15037876,  2.09057577, -2.09589362, -0.90173874,
#          0.56117936, -0.44985457,  1.2116322 , -0.1680555 ,  0.73744266,
#          1.66059651,  0.80921734,  0.347055  , -0.28110051,  0.93757992,
#          1.18273026,  0.03858847, -0.68605724,  0.27633452,  0.28533287]])

# %%
pca1= PCA().fit(X_std)

# %%
test=pca1.fit_transform(X_std)

# %%
# Out:
# array([[-2.83517148,  2.06288369, -1.49743484, ..., -0.22533626,
#          0.33363946, -0.01661735],
#        [-2.02888194, -0.17127715, -1.38272881, ..., -0.08834014,
#          0.0670143 , -0.0133629 ],
#        [-2.25645259,  0.63169171, -1.1764974 , ...,  0.11102845,
#         -0.59603005,  0.14274102],
#        ...,
#        [-4.22897407,  0.23809035, -0.48986165, ...,  0.16452722,
#         -0.20204876, -0.05870105],
#        [-3.05115832,  1.03288021,  0.52410351, ...,  0.08906527,
#         -0.03796248, -0.2870688 ],
#        [-2.95132756,  0.32161374, -0.2337291 , ...,  0.33003998,
#          0.02080279, -0.11866179]])

# %%
## Barchart 
plt.figure(figsize=(8,6),dpi=300)
plt.bar(range(44),pca.explained_variance_,alpha = .5,label = 'Indidual explained variance')
plt.xlabel('Explained Variance Ratio')
plt.ylabel('Principal components')
plt.legend(loc = 'best')

# %%
plt.figure(figsize=(8,6),dpi=300)
corr = pd.DataFrame(PCA().fit_transform(X_std)).corr()
sns.heatmap(corr,vmax=1,square = True,)
plt.title('Correlation bewteen PCAed features')
# Out:
# Text(0.5, 1.0, 'Correlation bewteen PCAed features')

# %%
from sklearn.decomposition import TruncatedSVD

# %%
svd = TruncatedSVD(n_components=2, n_iter=7, random_state=42)
X_2d = svd.fit_transform(X)

# %%
plt.figure(figsize=(8,6),dpi=300)
plt.scatter(X_2d[:,0],X_2d[:,1],c=y)
